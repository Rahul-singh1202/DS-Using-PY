# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mtcars_df = pd.read_csv(r"C:\Users\Rahul Singh\Desktop\Projects\DS Unisg PY\mt cars.csv")

plt.figure(figsize=(8, 6))
plt.hist(mtcars_df['qsec'], bins=10, color='skyblue', edgecolor='black')
plt.title('Frequency Distribution of qsec (Quarter-Mile Time)', fontsize=14)
plt.xlabel('qsec (Seconds)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()
